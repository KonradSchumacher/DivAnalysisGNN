# %%
import dbnomics
import pandas as pd

# %%
def fetch_interest_rates():
    print("Rufe Daten von DBnomics ab...")
    
    # 1. EZB: Hauptrefinanzierungssatz (Key Interest Rate)
    # Datensatz: ECB/FM (Financial market data)
    ecb_series = 'ECB/FM/D.U2.EUR.4F.KR.MRR_OD.LEV'
    
    # 2. FED: Effective Federal Funds Rate
    # Datensatz: FED/H15 (Selected Interest Rates)
    fed_series = 'FED/H15/RIFSPFF_N.D'

    try:
        # Abrufen der Zeitreihen
        df_ecb = dbnomics.fetch_series('OECD')
        return df_ecb

    except Exception as e:
        print(f"Fehler beim Abruf: {e}")
        return None

# Programm ausführen
df_ecb= fetch_interest_rates()
    
df_ecb
# Out:
# Rufe Daten von DBnomics ab...
# Fehler beim Abruf: Could not fetch data from URL 'https://api.db.nomics.world/v22/series?observations=1&series_ids=OECD&offset=0' because: Invalid value 'OECD' (str): Series ID 'OECD' must be formatted like 'provider_code/dataset_code/series_code' (at series_ids[0])
